# %% [markdown]
# ## Вариант 1
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы получаем должность) с сайтов HH(обязательно) и/или Superjob(по желанию). Приложение должно анализировать несколько страниц сайта (также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     Наименование вакансии.
#     Предлагаемую зарплату (разносим в три поля: минимальная и максимальная и валюта. цифры преобразуем к цифрам).
#     Ссылку на саму вакансию.
#     Сайт, откуда собрана вакансия.
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas. Сохраните в json либо csv.

# %% [markdown]
# Питоновский файл с кодом: https://github.com/PosyaginK/Parsing/blob/master/HW_2/task_2.py

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# Headers
HEADERS = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:90.0) Gecko/20100101 Firefox/90.0'
}

# %%
# Получаем html страницы по url
def get_html(url, params=''):
    response = requests.get(url, headers=HEADERS, params=params)
    return response

# %%
# HeadHanter
URL_HH = 'https://hh.ru/search/vacancy'

# SuperJob
HOST_SJ = 'https://superjob.ru' # Нужен для получения полных ссылок на вакансии.
URL_SJ = 'https://superjob.ru/vacancy/search/'

# %%
# Получаем контент со страницы html
def get_hh_content(response):
    soup = bs(response, 'lxml')
    items = soup.find_all('div', class_='vacancy-serp-item')
    hh_vacancy = []

    for item in items:
        hh_vacancy.append(
            {
                'site': 'HeadHanter', # Название сайта
                'title': item.find('div', class_='vacancy-serp-item__info').get_text(), # Название вакансии
                'link': item.find('div', class_='vacancy-serp-item__info').find('a').get('href'), # Ссылка на вакансию
                'salary': item.find('div', class_='vacancy-serp-item__sidebar'), # Зарплата
                'city': item.find('span', class_='vacancy-serp-item__meta-info').get_text(), # Город
                'organization': item.find('div', class_='vacancy-serp-item__meta-info-company').get_text(), # Название компании
                'note': item.find('div', class_='vacancy-label') # Примечание
            }
        )
    # Приведем данные к нормальному виду
    for i in hh_vacancy:
        # Salary
        try:
            i['salary'] = i['salary'].text
        except:
            i['salary'] = None
        if i['salary']:
            salary_list = i['salary'].split(' ')
            if salary_list[0] == 'от':
                i['salary_min'] = salary_list[1]
                i['salary_max'] = None
            elif salary_list[0] == 'до':
                i['salary_min'] = None
                i['salary_max'] = salary_list[1]
            else:
                i['salary_min'] = salary_list[0]
                i['salary_max'] = salary_list[2]
            i['salary_currency'] = salary_list[-1]
        else:
            i['salary_min'] = None
            i['salary_max'] = None
            i['salary_currency'] = None
        i.pop('salary')
        # note
        if i['note'] != None:
            i['note'] = i['note'].get_text()
        # City
        if i['city']:
            city_list = i['city'].split(',')
            i['city'] = city_list[0]
    return hh_vacancy

def superjob_get_content(html):
    soup = bs(html, 'lxml')
    items = soup.find_all('div', class_='f-test-vacancy-item')

    sj_vacancy = []
    for item in items:
        sj_vacancy.append(
            {
                'site': 'SuperJob',  # Название сайта
                'title': item.find('a').get_text(),  # Название вакансии
                'link': item.find('a').get('href'),  # Ссылка на вакансию
                'salary': item.find('span', class_='f-test-text-company-item-salary').get_text(),  # Зарплата
                'city': item.find('span', class_='f-test-text-company-item-location').get_text(),  # Город
                'organization': item.find('span', class_='f-test-text-vacancy-item-company-name').get_text(),
                # Название компании
                'note': item.find('span', class_='f-test-badge')  # Примечание
            }
        )
    # Почистим данные
    for v in sj_vacancy:
        # link
        v['link'] = HOST_SJ + v['link']
        # salary
        if v['salary'] != 'По договорённости':
            salary_list = v['salary'].split('\xa0')
            if salary_list[0] == 'от':
                v['salary_min'] = salary_list[1] + salary_list[2]
                v['salary_max'] = None
            elif salary_list[0] == 'до':
                v['salary_min'] = None
                v['salary_max'] = salary_list[1] + salary_list[2]
            elif len(salary_list) == 3:
                v['salary_min'] = salary_list[0] + salary_list[1]
                v['salary_max'] = salary_list[0] + salary_list[1]
            else:
                v['salary_min'] = salary_list[0] + salary_list[1]
                v['salary_max'] = salary_list[3] + salary_list[4]
            v['salary_currency'] = salary_list[-1].split('/')[0]
        else:
            v['salary_min'] = None
            v['salary_max'] = None
            v['salary_currency'] = None
        v.pop('salary')
        # note
        if v['note'] != None:
            v['note'] = v['note'].get_text()
        # city
        city_split = v['city'].split(' ')
        if len(city_split[2]) >= 3:
            v['city'] = city_split[2]
        else:
            v['city'] = city_split[3]
            
    return sj_vacancy

# %%
# Главные функции
def parser_hh():
    post = str(input('Введите название вакансии для парсинга: '))
    pages = int(input('Количество страниц для парсинга: '))
    html = get_html(URL)
    if html.status_code == 200:
        vacancy = []
        for page in range(1, pages + 1):
            print(f'Парсим страницу {page}')
            html = get_html(URL, params={'text': post, 'page': page})
            vacancy.extend(get_hh_content(html.text))
        hh_result = pd.DataFrame(vacancy)
    else:
        hh_result = html.status_code
    return hh_result

def parser_sj():
    POST = str(input('Введите название вакансии для парсинга: '))
    PAGES = int(input('Количество страниц для парсинга: '))
    html = get_html(URL)
    if html.status_code == 200:
        vacancy = []
        for page in range(1, PAGES + 1):
            print(f'Парсим страницу {page}')
            html = get_html(URL, params={'keywords': POST, 'page': page})
            vacancy.extend(superjob_get_content(html))
        sj_result = pd.DataFrame(vacancy)
    else:
        print('error')
    return sj_result

# %%
# ОБЪЕДИНИМ ПАРСИНГ ДВУХ САЙТОВ В ОДНУ ФУНКЦИЮ
def main_parsing():
    HH_URL = 'https://hh.ru/search/vacancy'
    SJ_URL = 'https://superjob.ru/vacancy/search/'

    post = str(input('Введите название вакансии для парсинга: '))
    pages = int(input('Количество страниц для парсинга: '))
    HH_HTML = get_html(HH_URL)
    SJ_HTML = get_html(SJ_URL)

    if HH_HTML.status_code == 200 and SJ_HTML.status_code == 200:
        vacancy = []
        for page in range(1, pages + 1):
            print(f'Парсятся страницы {page}')
            hh = get_html(HH_URL, params={'text': post, 'page': page})
            sj = get_html(SJ_URL, params={'keywords': post, 'page': page})
            vacancy.extend(get_hh_content(hh.text) + superjob_get_content(sj.text))
        result = pd.DataFrame(vacancy)
    else:
        print('error')
    return result

# %%
df = main_parsing()
df
# Out:
# Введите название вакансии для парсинга:  python
# Количество страниц для парсинга:  2
# Парсятся страницы 1
# Парсятся страницы 2
#           site                                              title  \
# 0   HeadHanter                             QA automation (Python)
# 1   HeadHanter  Бэкенд-разработчик (Python)/Middle Python/ Pyt...
# 2   HeadHanter                          Python Back-end Developer
# 3   HeadHanter                            Senior Python Developer
# 4   HeadHanter                                   Python-developer
# 5   HeadHanter                            Программист Python/Java
# 6   HeadHanter   Программист Python / Python Developer (удаленно)
# 7   HeadHanter                                 Разработчик Python
# 8   HeadHanter                            Middle Python Developer
# 9   HeadHanter  Backend-разработчик / Python developer (умные ...
# 10  HeadHanter  Python разработчик в области GIS (удаленная ра...
# 11  HeadHanter                         Программист Python Backend
# 12  HeadHanter                                   Python Developer
# 13  HeadHanter                                   Python developer
# 14  HeadHanter                                 Разработчик Python
# 15  HeadHanter  Бэкенд-разработчик Python/Middle Python/ Pytho...
# 16  HeadHanter       Программист Python (веб и мобильные проекты)
# 17  HeadHanter                         Back-end Developer(Python)
# 18  HeadHanter                                 Программист Python
# 19  HeadHanter                    Middle Python Engineer (Remote)
# 20    SuperJob                           Backend Developer Python
# 21    SuperJob  Специалист службы поддержки (с техническими зн...
# 22    SuperJob                                      IT-специалист
# 23    SuperJob                                     Программист 1С
# 24    SuperJob                  Backend-разработчик (PHP, Middle)
# 25    SuperJob                  Backend-разработчик (PHP, Junior)
# 26  HeadHanter                            Python Middle Developer
# 27  HeadHanter                                   Python Developer
# 28  HeadHanter                      Backend разработчик на python
# 29  HeadHanter                          Python developer (middle)
# 30  HeadHanter                                   Python-developer
# 31  HeadHanter                 Python (Django) программист Middle
# 32  HeadHanter                                     Data Scientist
# 33  HeadHanter                                 Программист Python
# 34  HeadHanter                        Python-разработчик (Middle)
# 35  HeadHanter       Python Backend Developer / WEB - разработчик
# 36  HeadHanter                 Back-end Python/Django разработчик
# 37  HeadHanter                                 Разработчик Python
# 38  HeadHanter                    Senior Python Engineer (Remote)
# 39  HeadHanter                                     Data Scientist
# 40  HeadHanter  Backend-разработчик / Python developer (умные ...
# 41  HeadHanter       Старший Backend-разработчик (Python, Django)
# 42  HeadHanter                                 Python разработчик
# 43  HeadHanter                      Python разработчик (middle +)
# 44  HeadHanter      Разработчик внутренней автоматизации (Python)
# 45  HeadHanter             Senior QA Automation Engineer (Python)
#
#                                                  link             city  \
# 0   https://perm.hh.ru/vacancy/48204586?from=vacan...           Москва
# 1   https://perm.hh.ru/vacancy/48421443?from=vacan...   Ростов-на-Дону
# 2   https://perm.hh.ru/vacancy/48441816?from=vacan...            Минск
# 3   https://perm.hh.ru/vacancy/47902679?from=vacan...           Москва
# 4   https://perm.hh.ru/vacancy/47546326?from=vacan...     Екатеринбург
# 5   https://perm.hh.ru/vacancy/43244378?from=vacan...           Москва
# 6   https://perm.hh.ru/vacancy/48247232?from=vacan...     Екатеринбург
# 7   https://perm.hh.ru/vacancy/46706157?from=vacan...           Москва
# 8   https://perm.hh.ru/vacancy/48045471?from=vacan...  Санкт-Петербург
# 9   https://perm.hh.ru/vacancy/48380601?from=vacan...          Воронеж
# 10  https://perm.hh.ru/vacancy/48457355?from=vacan...           Москва
# 9                    ООО Эктострой    Будьте первыми    100 000    200 000
# 10                         Atlatec              None        480        800
# 11     ИП Галлямов Раиль Нафисович              None       None    300 000
# 12                ООО АльтероСмарт    Будьте первыми    120 000    150 000
# 13                         Artezio    Будьте первыми    160 000       None
# 14                 Deltaplan Group              None    120 000       None
# 15             ЮТэйр, Авиакомпания    Будьте первыми    150 000    220 000
# 16                           Web++    Будьте первыми     40 000       None
# 17                   ООО ДВК Групп              None    100 000       None
# 18         Future Proof Technology    Будьте первыми      2 000      4 500
# 19                  Spark Equation    Будьте первыми    150 000    210 000
# 20                 Аналитикс Групп  Удаленная работа       None     100000
# 21                          Яндекс     Опыт не нужен      15000       None
# 22                      JOBCART.RU              None      40000       None
# 23                      СКБ Контур  Удаленная работа       None       None
# 24                          Виджет  Удаленная работа     110000       None
# 25                          Виджет              None      30000       None
# 26                ООО МКК Папазайм              None    120 000    180 000
# 27                   ТОО AVIATA.KZ              None       None       None
# 28                    ООО Флекскор              None     80 000       None
# 29                         Fitingo    Будьте первыми    150 000       None
# 30  ИП Черкасов Константин Юрьевич              None      1 000      2 000
# 31                 ООО ЭКСПЕРТ-ПРО              None     90 000       None
# 32                   ООО Артистраж              None     60 000    200 000
# 33                        Сбер. IT              None       None       None
# 34                          Латера    Будьте первыми       None    220 000
# 35             ООО Перфект Системс    Будьте первыми    185 000       None
# 36                ООО Mind&Machine    Будьте первыми    150 000       None
# 37                          Билайн              None       None       None
# 38                  Spark Equation    Будьте первыми    230 000    320 000
# 39                           Точка    Будьте первыми       None    300 000
# 40                   ООО Эктострой    Будьте первыми    100 000    200 000
# 41                          Ergeon    Будьте первыми      4 000      5 000
# 42                        Сбер. IT              None       None       None
# 43                ООО МЕДИКАЛ НОУТ              None    120 000    180 000
# 44                        СберИгры              None       None       None
# 45              Scalable Solutions    Будьте первыми    300 000       None
#
#    salary_currency
# 0             руб.
# 1             руб.
# 2             None
# 3             руб.
# 4             руб.
# 5             руб.
# 6             руб.
# 7             None
# 8             руб.
# 9             руб.
# 10             EUR
# 11            руб.
# 12            руб.
# 13            руб.
# 14            руб.
# 15            руб.
# 16            руб.
# 17            руб.
# 18             USD
# 19            руб.
# 20            руб.
# 21            руб.
# 22            руб.
# 23            None
# 24            руб.
# 25            руб.
# 26            руб.
# 27            None
# 28            руб.
# 29            руб.
# 30             USD
# 31            руб.
# 32            руб.
# 33            None
# 34            руб.
# 35            руб.
# 36            руб.
# 37            None
# 38            руб.
# 39            руб.
# 40            руб.
# 41             USD
# 42            None
# 43            руб.
# 44            None
# 45            руб.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   site             46 non-null     object
#  1   title            46 non-null     object
#  2   link             46 non-null     object
#  3   city             46 non-null     object
#  4   organization     46 non-null     object
#  5   note             24 non-null     object
#  6   salary_min       34 non-null     object
#  7   salary_max       22 non-null     object
#  8   salary_currency  38 non-null     object
# dtypes: object(9)
# memory usage: 3.4+ KB

# %%
tt = df.to_csv
